# %%
from google.cloud import storage
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from google.cloud import storage
#
# ModuleNotFoundError: No module named 'google'

# %%
client = storage.Client.from_service_account_json("gcskey.json")

# %%
bucket = client.get_bucket("puma1011-gcs")
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# <ipython-input-12-82c660adf58a> in <module>
# ----> 1 bucket = client.get_bucket("puma1011-gcs")
#
# ~\anaconda3\lib\site-packages\google\cloud\storage\client.py in get_bucket(self, bucket_or_name, timeout, if_metageneration_match, if_metageneration_not_match, retry)
#     780         """
#     781         bucket = self._bucket_arg_to_bucket(bucket_or_name)
# --> 782         bucket.reload(
#     783             client=self,
#     784             timeout=timeout,
#
# ~\anaconda3\lib\site-packages\google\cloud\storage\bucket.py in reload(self, client, projection, timeout, if_etag_match, if_etag_not_match, if_metageneration_match, if_metageneration_not_match, retry)
#    1027             (Optional) How to retry the RPC. See: :ref:`configuring_retries`
#    1028         """
# -> 1029         super(Bucket, self).reload(
# ...

# %%
blob = bucket.blob("187.txt")
blob.upload_from_string("Moin")
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# <ipython-input-13-cc7f72ae0135> in <module>
#       1 blob = bucket.blob("187.txt")
# ----> 2 blob.upload_from_string("Moin")
#
# ~\anaconda3\lib\site-packages\google\cloud\storage\blob.py in upload_from_string(self, data, content_type, num_retries, client, predefined_acl, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    2842         data = _to_bytes(data, encoding="utf-8")
#    2843         string_buffer = BytesIO(data)
# -> 2844         self.upload_from_file(
#    2845             file_obj=string_buffer,
#    2846             size=len(data),
#
# ...

# %%
blob.download_as_string()
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# <ipython-input-14-7611a2f24818> in <module>
# ----> 1 blob.download_as_string()
#
# ~\anaconda3\lib\site-packages\google\cloud\storage\blob.py in download_as_string(self, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, retry)
#    1518             _DOWNLOAD_AS_STRING_DEPRECATED, PendingDeprecationWarning, stacklevel=2
#    1519         )
# -> 1520         return self.download_as_bytes(
#    1521             client=client,
#    1522             start=start,
#
# ...
